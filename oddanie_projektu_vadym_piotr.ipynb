# %% [markdown]
# # TECHNIKI PROGRAMOWANIA - projekt 3
# ### Vadym Zelenko 192448
# ### Piotr Suchodolski 203441
#
# Wykorzystane biblioteki:
# - matplotplusplus (c++)
# - Pybind

# %%
import signal_lib #import modułu C++

# %% [markdown]
# # Sygnał sin, cos, prostokątny

# %%
sin_signal = signal_lib.generate_sin(3, 100, 500)
cos_signal = signal_lib.generate_cos(3, 100, 500)
square_signal = signal_lib.generate_square(3, 100, 500)

# %% [markdown]
# ![Screenshot 2025-05-31 at 11.15.27.png](attachment:d59be88e-647f-410e-b685-b48e210dbe6d.png)

# %%
# Sygnał + szum
add_noise_to_signal(sin_signal)

# %% [markdown]
# ![Screenshot 2025-05-31 at 11.20.13.png](attachment:c7741044-5a67-45d4-a2de-51a5f441a469.png)

# %%
# Filtr dolnoprzepustowy
apply_low_pass_filter(sin_signal)

# %% [markdown]
# ![Screenshot 2025-05-31 at 11.23.02.png](attachment:2398c800-4361-4e55-9c26-01f799c88b56.png)

# %%
# Pochodna sygnału
calculate_signal_derivative(sin_signal)

# %% [markdown]
# ![Screenshot 2025-05-31 at 11.23.26.png](attachment:c28bc90a-bf9c-4d1c-9186-b6cc642b3faa.png)

# %%
# Wykrywanie krawędzi
detect_edges(sin_signal)

# %% [markdown]
# ![Screenshot 2025-05-31 at 11.24.01.png](attachment:0a7c2a78-1dce-4740-9d42-86d80ccdd64f.png)

# %%
# Progowanie sygnału
threshold_signal(sin_signal)

# %% [markdown]
# ![Screenshot 2025-05-31 at 11.24.47.png](attachment:c96ff0eb-4eb6-472c-840a-859dba5dd4c1.png)

# %%
# Usuwanie niskich częstotliwości
remove_low_frequencies(sin_signal)

# %% [markdown]
# ![Screenshot 2025-05-31 at 11.25.05.png](attachment:e79a93f8-fb1b-4637-afd9-4b0d7895ddbb.png)

# %%
# Usuwanie wysokich częstotliwości
remove_high_frequencies(sin_signal)

# %% [markdown]
# ![Screenshot 2025-05-31 at 11.25.22.png](attachment:d5d00fe5-9062-4c4c-93c9-3cbe96101397.png)

# %%
# Detekcja pików
detect_peaks(sin_signal)

# %% [markdown]
# ![Screenshot 2025-05-31 at 11.25.49.png](attachment:0ced35e5-abb2-420a-8a4a-956e5525200f.png)

# %%
# Autokorelacja
compute_autocorrelation(sin_signal)

# %% [markdown]
# ![Screenshot 2025-05-31 at 11.26.05.png](attachment:4b0f9d3b-5831-40cd-8a9c-eb19dea196af.png)
